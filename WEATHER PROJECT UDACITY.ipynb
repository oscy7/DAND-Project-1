# %%
import pandas as pd

# %%
df1 = pd.read_csv("results city_data.csv", index_col = 'year')
df2 = pd.read_csv("results city_list.csv")
df3 = pd.read_csv("results global_data.csv", index_col = 'year')

# %%
df3_rename = df3.rename(columns = {'avg_temp':'avg_global_temp'})
df1_rename = df1.rename(columns = {'avg_temp':'avg_LA_temp'})

# %%
df1_rename.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df = pd.concat([df1_rename, df2,df3_rename])
df.plot()
# Out:
# <AxesSubplot:>

# %%
df_1849_global = df3_rename.loc['1849':'2013']

# %%
df_1849_global.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df_x = pd.concat([df1_rename,df2,df_1849_global])
df_x.plot()
# Out:
# <AxesSubplot:>

# %%
df_x.rolling(10).mean().plot(figsize = (10,5))
# Out:
# <AxesSubplot:>

# %%
df_x.rolling(5).mean().plot(figsize = (10,5))
# Out:
# <AxesSubplot:>
